# %% [markdown]
# # Fine-Tuning YOLOV8M on Annotated Data

# %%
# Use the official Apple-optimized PyTorch
# pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/metal.html

# %%
import torch
print(torch.backends.mps.is_available())  # Should return True

# %% [markdown]
# ## Imports

# %%
from ultralytics import YOLO
import os

# %% [markdown]
# # Configuration

# %%
yaml_path = './Model1_local/Model_Training_Data/data.yaml'               # Path to your dataset YAML
video_dir = '../Dataset/Video'               # Folder with input test videos
output_dir = '../Results/Model1_local'            # Output folder for annotated videos
pretrained_model = './Pre-trained_Models/yolov8m.pt'          # Model variant: yolov8n/s/m/l/x.pt
epochs = 60                             # Training epochs (iterations)

# %%
print(" Starting YOLOv8 training...")
model = YOLO(pretrained_model)
model.train(data=yaml_path, epochs=epochs)
print(" Training complete.\n")

# %% [markdown]
# ## Load Best Model

# %%
# ls ../runs/detect/train2/weights/best.pt

# %%
trained_model = YOLO('../runs/detect/train2/weights/best.pt') # change to best model path

# %% [markdown]
# # Test on Videos

# %%
os.makedirs(output_dir, exist_ok=True) # Output directory for annotated videos

print("🎬 Running inference on test videos...\n")
for file in os.listdir(video_dir):
    if file.lower().endswith(('.mp4', '.mov', '.avi', '.mkv')):
        video_path = os.path.join(video_dir, file)
        name_prefix = os.path.splitext(file)[0]

        print(f"🔍 Processing: {file}")
        trained_model.predict(
            source=video_path,
            save=True,
            save_txt=False,
            save_conf=True,
            project=output_dir,
            name=f"annotated_{name_prefix}"
        )

print("\n All videos processed. Check the 'output_videos' folder.")
# Out:
# 🎬 Running inference on test videos...
#
# 🔍 Processing: test_vid_4.mp4
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 21 Fruits, 121.4ms
# video 1/1 (frame 2/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 19 Fruits, 108.6ms
# video 1/1 (frame 3/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 14 Fruits, 104.4ms
# video 1/1 (frame 4/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 14 Fruits, 99.7ms
# video 1/1 (frame 5/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 13 Fruits, 109.0ms
# video 1/1 (frame 6/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 16 Fruits, 134.2ms
# video 1/1 (frame 7/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 11 Fruits, 131.3ms
# video 1/1 (frame 8/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 8 Fruits, 127.2ms
# video 1/1 (frame 9/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 9 Fruits, 114.5ms
# video 1/1 (frame 10/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 11 Fruits, 106.4ms
# video 1/1 (frame 11/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 13 Fruits, 99.9ms
# video 1/1 (frame 12/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 21 Fruits, 113.0ms
# video 1/1 (frame 13/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 15 Fruits, 125.8ms
# video 1/1 (frame 14/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 10 Fruits, 118.2ms
# video 1/1 (frame 15/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 8 Fruits, 1 pallet, 108.9ms
# video 1/1 (frame 16/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 7 Fruits, 1 pallet, 98.3ms
# video 1/1 (frame 17/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 13 Fruits, 128.4ms
# video 1/1 (frame 18/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 13 Fruits, 166.8ms
# video 1/1 (frame 19/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 12 Fruits, 103.4ms
# video 1/1 (frame 20/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 8 Fruits, 101.8ms
# video 1/1 (frame 21/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 4 Fruits, 96.2ms
# video 1/1 (frame 22/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 (no detections), 113.5ms
# video 1/1 (frame 23/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 2 Fruits, 150.0ms
# video 1/1 (frame 24/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 3 Fruits, 97.2ms
# video 1/1 (frame 25/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 6 Fruits, 97.0ms
# video 1/1 (frame 26/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640 3 Fruits, 101.0ms
# video 1/1 (frame 27/369) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_4.mp4: 384x640
1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 151.1ms
# video 1/1 (frame 860/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 211.5ms
# video 1/1 (frame 861/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 146.2ms
# video 1/1 (frame 862/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 241.5ms
# video 1/1 (frame 863/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 128.3ms
# video 1/1 (frame 864/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 135.2ms
# video 1/1 (frame 865/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 156.5ms
# video 1/1 (frame 866/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 146.0ms
# video 1/1 (frame 867/1436) /Users/mostafa/Desktop/FactorySupervision/Our_Models/../Dataset/Video/test_vid_1.mp4: 384x640 4 pallets, 150.8ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 10
#       7         name_prefix = os.path.splitext(file)[0]
#       9         print(f"🔍 Processing: {file}")
# ---> 10         trained_model.predict(
#      11             source=video_path,
#      12             save=True,
#      13             save_txt=False,
#      14             save_conf=True,
#      15             project=output_dir,
#      16             name=f"annotated_{name_prefix}"
#      17         )
#      19 print("\n All videos processed. Check the 'output_videos' folder.")
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/engine/model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:227, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     225     return self.stream_inference(source, model, *args, **kwargs)
#     226 else:
# --> 227     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:57, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      54         else:
#      55             # Pass the last request to the generator and get its response
#      56             with ctx_factory():
# ---> 57                 response = gen.send(request)
#      59 # We let the exceptions raised above by the generator's `.throw` or
#      60 # `.send` methods bubble up to our caller, except for StopIteration
#      61 except StopIteration as e:
#      62     # The generator informed us that it is done: take whatever its
#      63     # returned value (if any) was and indicate that we're done too
#      64     # by returning it (see docs for python's return-statement).
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     328 # Inference
#     329 with profilers[1]:
# --> 330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:646, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     644 # PyTorch
#     645 if self.pt or self.nn_module:
# --> 646     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     648 # TorchScript
#     649 elif self.jit:
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:318, in C2f.forward(self, x)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:318, in <genexpr>(.0)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:495, in Bottleneck.forward(self, x)
#     493 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     494     """Apply bottleneck with optional shortcut connection."""
# --> 495     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:92, in Conv.forward_fuse(self, x)
#      82 def forward_fuse(self, x):
#      83     """
#      84     Apply convolution and activation without batch normalization.
#      85
#    (...)
#      90         (torch.Tensor): Output tensor.
#      91     """
# ---> 92     return self.act(self.conv(x))
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Desktop/FactorySupervision/tf-venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
