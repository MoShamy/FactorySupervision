# %%
import cv2
import time
from ultralytics import YOLO
import json
import numpy as np

# %%
# Load the video
video_path = "testVid/test_vid_2.mp4"
cap = cv2.VideoCapture(video_path)
model = YOLO("models/yolov8m.pt")

# %%
# output video writer
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
out = cv2.VideoWriter('resultVid/output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# %%
# vertiical line position (middle of frame but can tweak it a lot)
line_x = int(width * 0.5)

# %%
with open('calibration.json', 'r') as f:
    calibration_data = json.load(f)

# Extract threshold from calibration data
cross_threshold = calibration_data.get("threshold", 3)
# Initialize time and threshold for product movement would change depending on machine normal
last_cross_time = time.time()

# %%
prev_centroids = []

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 inference

    results = model(frame) 
    detections = results[0].boxes.xyxy.cpu().numpy()

    curr_centroids = []
    crossed_this_frame = False

    for x1, y1, x2, y2 in detections:
        cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
        curr_centroids.append((cx, cy))

        # Draw bounding box and centroid
        cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 255, 0), 2)
        cv2.circle(frame, (cx, cy), 5, (0, 255, 0), -1)

        # Line crossing check (left to right)
        for pcx, pcy in prev_centroids:
            if pcx < line_x and cx >= line_x: #Currently crossing
                crossed_this_frame = True
                last_cross_time = time.time()

    # Draw vertical line
    cv2.line(frame, (line_x, 0), (line_x, height), (0, 0, 255), 2)

    # Calculate time since last crossing
    time_since_last_cross = time.time() - last_cross_time
    production_status = "Running" if time_since_last_cross < cross_threshold else "Stopped"
    color = (0, 255, 0) if production_status == "Running" else (0, 0, 255)

    # Display status at the top-left corner
    cv2.putText(frame, f"Production: {production_status}", (30, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 2, color, 3)

    cv2.putText(frame, f"Time since last object: {time_since_last_cross:.2f}", (30,120),cv2.FONT_HERSHEY_SIMPLEX, 2, color, 3)

    # Update previous centroids
    prev_centroids = curr_centroids
    out.write(frame)
    cv2.imshow("YOLOv8 + DeepSORT Tracking", frame)
    if cv2.waitKey(21) & 0xFF == 27:  # ESC to quit
        break
    

cap.release()
out.release()
# Out:
# 0: 384x640 4 bottles, 110.7ms
# Speed: 4.3ms preprocess, 110.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bottles, 103.6ms
# Speed: 1.3ms preprocess, 103.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 98.5ms
# Speed: 1.2ms preprocess, 98.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 99.5ms
# Speed: 1.4ms preprocess, 99.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bottles, 99.0ms
# Speed: 1.3ms preprocess, 99.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 97.7ms
# Speed: 1.2ms preprocess, 97.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bottles, 98.4ms
# Speed: 1.4ms preprocess, 98.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 97.3ms
# Speed: 1.1ms preprocess, 97.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bottles, 97.7ms
# Speed: 1.1ms preprocess, 97.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 bottles, 99.1ms
# Speed: 1.2ms preprocess, 99.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 bottles, 93.1ms
# Speed: 1.2ms preprocess, 93.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 92.2ms
# Speed: 1.1ms preprocess, 92.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 94.2ms
# Speed: 1.3ms preprocess, 94.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 bottles, 99.6ms
# Speed: 1.2ms preprocess, 99.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 bottles, 98.9ms
# Speed: 1.2ms preprocess, 98.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 bottles, 97.7ms
# Speed: 1.3ms preprocess, 97.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 98.0ms
# Speed: 1.1ms preprocess, 98.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 98.6ms
# Speed: 1.2ms preprocess, 98.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 93.2ms
# Speed: 1.1ms preprocess, 93.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 93.1ms
# Speed: 1.3ms preprocess, 93.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 93.9ms
# Speed: 1.1ms preprocess, 93.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 94.7ms
# Speed: 1.1ms preprocess, 94.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 92.5ms
# Speed: 1.1ms preprocess, 92.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 92.3ms
# Speed: 1.1ms preprocess, 92.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bottles, 1 sink, 94.3ms
# Speed: 1.1ms preprocess, 94.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 93.0ms
# Speed: 1.3ms preprocess, 93.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 94.3ms
# Speed: 1.1ms preprocess, 94.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 92.4ms
# Speed: 1.1ms preprocess, 92.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 95.1ms
# Speed: 1.2ms preprocess, 95.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles, 1 cup, 94.1ms
# Speed: 1.2ms preprocess, 94.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 bottles,